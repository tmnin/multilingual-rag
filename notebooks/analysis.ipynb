# %%
import matplotlib.pyplot as plt

noise = [r["noise"] for r in results]
r1 = [r["recall@1"] for r in results]
r5 = [r["recall@5"] for r in results]

plt.plot(noise, r1, label="Recall@1")
plt.plot(noise, r5, label="Recall@5")
plt.xlabel("Noise Probability")
plt.ylabel("Recall")
plt.title("Retrieval Robustness under Textual Noise")
plt.legend()
plt.show()
